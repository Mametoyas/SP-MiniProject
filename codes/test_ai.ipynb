# %% [markdown]
# # Hangman AI — Test Notebook

# %%
from predict import predict

# %% [markdown]
# ## ทดสอบ Manual

# %%
pattern = "_______"   # _ = ยังไม่รู้
guessed = set()       # ตัวที่เดาถูก
wrong   = set()       # ตัวที่เดาผิด

suggest = predict(pattern, guessed, wrong)
print(f"pattern : {pattern}")
print(f"suggest : {suggest}")
# Out:
# pattern : _______
# suggest : ['a', 'r', 'i', 'e', 'l']

# %% [markdown]
# ## จำลองเล่นเกม Hangman ทีละตัว

# %%
MAX_WRONG = 8

def play(secret: str):
    secret  = secret.lower()
    guessed = set()
    wrong   = set()

    for turn in range(1, 100):
        pattern = "".join(c if c in guessed else "_" for c in secret)

        if "_" not in pattern:
            print(f"✅ WIN in {turn-1} turns! word = {secret}")
            return

        if len(wrong) >= MAX_WRONG:
            print(f"❌ LOSE — word was: {secret}")
            return

        suggest = predict(pattern, guessed, wrong)
        guess   = suggest[0]          # AI เลือกตัวแรกเสมอ

        if guess in secret:
            guessed.add(guess)
            result = "✓"
        else:
            wrong.add(guess)
            result = "✗"

        print(f"turn {turn:2d} | pattern: {pattern:15s} | guess: {guess} {result} | wrong({len(wrong)}): {sorted(wrong)}")

# %%
play("banana")
# Out:
# turn  1 | pattern: ______          | guess: a ✓ | wrong(0): []
# turn  2 | pattern: _a_a_a          | guess: n ✓ | wrong(0): []
# turn  3 | pattern: _anana          | guess: d ✗ | wrong(1): ['d']
# turn  4 | pattern: _anana          | guess: b ✓ | wrong(1): ['d']
# ✅ WIN in 4 turns! word = banana

# %% [markdown]
# ## ทดสอบหลายคำพร้อมกัน

# %%
test_words = ["elephant", "python", "banana", "tiger", "brazil", "strawberry"]

for word in test_words:
    play(word)
    print()
# Out:
# turn  1 | pattern: ________        | guess: a ✓ | wrong(0): []
# turn  2 | pattern: _____a__        | guess: c ✗ | wrong(1): ['c']
# turn  3 | pattern: _____a__        | guess: r ✗ | wrong(2): ['c', 'r']
# turn  4 | pattern: _____a__        | guess: l ✓ | wrong(2): ['c', 'r']
# turn  5 | pattern: _l___a__        | guess: o ✗ | wrong(3): ['c', 'o', 'r']
# turn  6 | pattern: _l___a__        | guess: g ✗ | wrong(4): ['c', 'g', 'o', 'r']
# turn  7 | pattern: _l___a__        | guess: n ✓ | wrong(4): ['c', 'g', 'o', 'r']
# turn  8 | pattern: _l___an_        | guess: t ✓ | wrong(4): ['c', 'g', 'o', 'r']
# turn  9 | pattern: _l___ant        | guess: p ✓ | wrong(4): ['c', 'g', 'o', 'r']
# turn 10 | pattern: _l_p_ant        | guess: b ✗ | wrong(5): ['b', 'c', 'g', 'o', 'r']
# turn 11 | pattern: _l_p_ant        | guess: e ✓ | wrong(5): ['b', 'c', 'g', 'o', 'r']
# turn 12 | pattern: elep_ant        | guess: d ✗ | wrong(6): ['b', 'c', 'd', 'g', 'o', 'r']
# turn 13 | pattern: elep_ant        | guess: f ✗ | wrong(7): ['b', 'c', 'd', 'f', 'g', 'o', 'r']
# turn 14 | pattern: elep_ant        | guess: h ✓ | wrong(7): ['b', 'c', 'd', 'f', 'g', 'o', 'r']
# ✅ WIN in 14 turns! word = elephant
#
# turn  1 | pattern: ______          | guess: a ✗ | wrong(1): ['a']
# turn  2 | pattern: ______          | guess: e ✗ | wrong(2): ['a', 'e']
# turn  3 | pattern: ______          | guess: o ✓ | wrong(2): ['a', 'e']
# turn  4 | pattern: ____o_          | guess: n ✓ | wrong(2): ['a', 'e']
# turn  5 | pattern: ____on          | guess: l ✗ | wrong(3): ['a', 'e', 'l']
# turn  6 | pattern: ____on          | guess: s ✗ | wrong(4): ['a', 'e', 'l', 's']
# turn  7 | pattern: ____on          | guess: p ✓ | wrong(4): ['a', 'e', 'l', 's']
# turn  8 | pattern: p___on          | guess: i ✗ | wrong(5): ['a', 'e', 'i', 'l', 's']
# turn  9 | pattern: p___on          | guess: g ✗ | wrong(6): ['a', 'e', 'g', 'i', 'l', 's']
# turn 10 | pattern: p___on          | guess: b ✗ | wrong(7): ['a', 'b', 'e', 'g', 'i', 'l', 's']
# turn 11 | pattern: p___on          | guess: c ✗ | wrong(8): ['a', 'b', 'c', 'e', 'g', 'i', 'l', 's']
# ❌ LOSE — word was: python
#
# turn  1 | pattern: ______          | guess: a ✓ | wrong(0): []
# turn  2 | pattern: _a_a_a          | guess: n ✓ | wrong(0): []
# turn  3 | pattern: _anana          | guess: d ✗ | wrong(1): ['d']
# turn  4 | pattern: _anana          | guess: b ✓ | wrong(1): ['d']
# ✅ WIN in 4 turns! word = banana
#
# turn  1 | pattern: _____           | guess: a ✗ | wrong(1): ['a']
# turn  2 | pattern: _____           | guess: e ✓ | wrong(1): ['a']
# turn  3 | pattern: ___e_           | guess: r ✓ | wrong(1): ['a']
# turn  4 | pattern: ___er           | guess: i ✓ | wrong(1): ['a']
# turn  5 | pattern: _i_er           | guess: g ✓ | wrong(1): ['a']
# turn  6 | pattern: _iger           | guess: n ✗ | wrong(2): ['a', 'n']
# turn  7 | pattern: _iger           | guess: b ✗ | wrong(3): ['a', 'b', 'n']
# turn  8 | pattern: _iger           | guess: c ✗ | wrong(4): ['a', 'b', 'c', 'n']
# turn  9 | pattern: _iger           | guess: d ✗ | wrong(5): ['a', 'b', 'c', 'd', 'n']
# turn 10 | pattern: _iger           | guess: f ✗ | wrong(6): ['a', 'b', 'c', 'd', 'f', 'n']
# turn 11 | pattern: _iger           | guess: h ✗ | wrong(7): ['a', 'b', 'c', 'd', 'f', 'h', 'n']
# turn 12 | pattern: _iger           | guess: j ✗ | wrong(8): ['a', 'b', 'c', 'd', 'f', 'h', 'j', 'n']
# ❌ LOSE — word was: tiger
#
# turn  1 | pattern: ______          | guess: a ✓ | wrong(0): []
# turn  2 | pattern: __a___          | guess: r ✓ | wrong(0): []
# turn  3 | pattern: _ra___          | guess: e ✗ | wrong(1): ['e']
# turn  4 | pattern: _ra___          | guess: l ✓ | wrong(1): ['e']
# turn  5 | pattern: _ra__l          | guess: s ✗ | wrong(2): ['e', 's']
# turn  6 | pattern: _ra__l          | guess: i ✓ | wrong(2): ['e', 's']
# turn  7 | pattern: _ra_il          | guess: b ✓ | wrong(2): ['e', 's']
# turn  8 | pattern: bra_il          | guess: z ✓ | wrong(2): ['e', 's']
# ✅ WIN in 8 turns! word = brazil
#
# turn  1 | pattern: __________      | guess: e ✓ | wrong(0): []
# turn  2 | pattern: ______e___      | guess: r ✓ | wrong(0): []
# turn  3 | pattern: __r___err_      | guess: s ✓ | wrong(0): []
# turn  4 | pattern: s_r___err_      | guess: w ✓ | wrong(0): []
# turn  5 | pattern: s_r_w_err_      | guess: a ✓ | wrong(0): []
# turn  6 | pattern: s_raw_err_      | guess: b ✓ | wrong(0): []
# turn  7 | pattern: s_rawberr_      | guess: t ✓ | wrong(0): []
# turn  8 | pattern: strawberr_      | guess: y ✓ | wrong(0): []
# ✅ WIN in 8 turns! word = strawberry

# %% [markdown]
# ## Win Rate Test (random sample)

# %%
import random

with open("../datasets/words.txt", encoding="utf8") as f:
    all_words = [w.strip().lower() for w in f if w.strip().isalpha()]

sample = random.sample(all_words, min(200, len(all_words)))

MAX_WRONG = 6
wins = 0

for secret in sample:
    guessed, wrong = set(), set()
    for _ in range(100):
        pattern = "".join(c if c in guessed else "_" for c in secret)
        if "_" not in pattern:
            wins += 1
            break
        if len(wrong) >= MAX_WRONG:
            break
        guess = predict(pattern, guessed, wrong)[0]
        (guessed if guess in secret else wrong).add(guess)

print(f"Win Rate: {wins}/{len(sample)} = {wins/len(sample)*100:.1f}%")
# Out:
# Win Rate: 170/200 = 85.0%
